# %% [markdown]
# # AWS Glue DB Upload
#
# This notebook will be responsible for leveraging AWS Glue to create a table within the raw_data database, which was created within the dependencies folder during setup.

# %%
# import libraries
import boto3
import time
from botocore.exceptions import ClientError

# %%
# set up glue client and parameters
glue = boto3.client('glue')

crawler_name = 'raw_crawler'
database_name = 'raw_data'
s3_target = 's3://group9-ml-proj-raw-data-bucket-grw/data/raw_merged_data.csv'
glue_role = 'LabRole'

# %%
# create crawler for raw data
try:
    response = glue.create.crawler(
        Name=crawler_name,
        Role=glue_role,
        DatabaseName=database_name,
        Targets={'S3Targets': [{'Path': s3_target}]}
    )
    print(f"Crawler '{crawler_name}' created successfully.")
except glue.exceptions.AlreadyExistsException:
    print(f"Crawler ' {crawler_name}' already exists.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 # create crawler for raw data
#       2 try:
# ----> 3     response = glue.create.crawler(
#       4         Name=crawler_name,
#       5         Role=glue_role,
#       6         DatabaseName=database_name,
#       7         Targets={'S3Targets': [{'Path': s3_target}]}
#       8     )
#       9     print(f"Crawler '{crawler_name}' created successfully.")
#      10 except glue.exceptions.AlreadyExistsException:
#
# File /opt/conda/lib/python3.11/site-packages/botocore/client.py:923, in BaseClient.__getattr__(self, item)
#     920 if event_response is not None:
#     921     return event_response
# --> 923 raise AttributeError(
#     924     f"'{self.__class__.__name__}' object has no attribute '{item}'"
#     925 )
#
# AttributeError: 'Glue' object has no attribute 'create'

# %%
# run the crawler
glue.start_crawler(Name=crawler_name)

# %%
# check the raw_data database
response = glue.get_tables(DatabaseName=database_name)

print(f"Tables in '{database_name}' database:")
for table in response['TableList']:
    print(table['Name'])
